# %% [markdown]
# ## Experiment

# %%
import pandas as pd
data = pd.DataFrame({'x': [1, 2, 3]})
# Out:
# loaded

# %%
lr = 0.01
accuracy = 0.80
accuracy
# Out:
# 0.84

# %%
print('done')
# Out:
# done

# %% [raw]
# Raw cell notes.

# %% [markdown]
# End summary updated.
